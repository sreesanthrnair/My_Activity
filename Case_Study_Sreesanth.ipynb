# %% [markdown]
# <a href="https://colab.research.google.com/github/sreesanthrnair/My_Activity/blob/main/Case_Study_Sreesanth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
population = pd.read_csv('/content/population.csv')
population
# Out:
#            country  population
# 0    United States  1278642419
# 1            China   792846414
# 2            India  1001406378
# 3            Japan  1206263687
# 4          Germany   428734972
# 5           Russia   420968276
# 6           Brazil   675094950
# 7   United Kingdom   674991378
# 8           France   434389014
# 9            Italy   254467210
# 10          Canada  1438267572
# 11       Australia   439285667
# 12     South Korea   618608295
# 13           Spain   898664919
# 14          Mexico   653061058
# 15       Indonesia    93409749
# 16          Turkey   247285876
# 17    Saudi Arabia   958477463
# 18       Argentina  1432830251
# 19    South Africa   916989541

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     20 non-null     object
#  1   population  20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
gdp = pd.read_excel('/content/gdp.xlsx')
gdp
# Out:
#            Country             GDP
# 0    United States  10450436373455
# 1            China   5086547998939
# 2            India  14540718118693
# 3            Japan  12473835857216
# 4          Germany   2038442396490
# 5           Russia  10987125474745
# 6           Brazil   8793052816619
# 7   United Kingdom  11799848684255
# 8           France   7758669752269
# 9            Italy  12907234326850
# 10          Canada   8158351525190
# 11       Australia   5444267975247
# 12     South Korea   6562909541266
# 13           Spain  15275513099842
# 14          Mexico   2775281278756
# 15       Indonesia  12404144955318
# 16          Turkey   2581127745611
# 17    Saudi Arabia   8855399647233
# 18       Argentina   8767336567320
# 19    South Africa   3328747361982

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  20 non-null     object
#  1   GDP      20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
internet_users = pd.read_json('/content/internet_users.json')
internet_users
# Out:
#            country  internet_users
# 0    United States       745595490
# 1            China       685275917
# 2            India       606850704
# 3            Japan      1112451555
# 4          Germany       246827121
# 5           Russia       162156967
# 6           Brazil        24027075
# 7   United Kingdom       266047041
# 8           France       216417853
# 9            Italy        87191493
# 10          Canada       894102645
# 11       Australia       201619113
# 12     South Korea       291770691
# 13           Spain       794943861
# 14          Mexico       135489564
# 15       Indonesia         4584702
# 16          Turkey       128924625
# 17    Saudi Arabia       108944665
# 18       Argentina       421477197
# 19    South Africa       739194223

# %%
internet_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         20 non-null     object
#  1   internet_users  20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
literacy_rate = pd.read_xml('/content/literacy_rate.xml')
literacy_rate
# Out:
#               name  literacy_rate
# 0    United States           72.7
# 1            China           82.2
# 2            India           80.3
# 3            Japan           97.5
# 4          Germany           92.9
# 5           Russia           89.1
# 6           Brazil           81.0
# 7   United Kingdom           82.9
# 8           France           97.6
# 9            Italy           83.7
# 10          Canada           70.8
# 11       Australia           71.6
# 12     South Korea           66.4
# 13           Spain           60.6
# 14          Mexico           76.5
# 15       Indonesia           75.4
# 16          Turkey           71.4
# 17    Saudi Arabia           60.5
# 18       Argentina           67.8
# 19    South Africa           87.7

# %%
literacy_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           20 non-null     object
#  1   literacy_rate  20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes

# %%
gdp.rename(columns={'Country':'country'}, inplace=True)
literacy_rate.rename(columns={'name':'country'}, inplace=True)

# %%
merged_df = pd.merge(population, gdp, on='country', how='inner')
merged_df = pd.merge(merged_df, internet_users, on='country', how='inner')
merged_df = pd.merge(merged_df, literacy_rate, on='country', how='inner')

# %%
merged_df
# Out:
#            country  population             GDP  internet_users  literacy_rate
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
merged_df['internet_penetration_rate'] = merged_df['internet_users']/merged_df['population'] * 100

# %%
merged_df
# Out:
#            country  population             GDP  internet_users  literacy_rate  \
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
# Find countries with highest internet penetration rates
merged_df.sort_values(by='internet_penetration_rate', ascending=False).head(3)
# Out:
#    country  population             GDP  internet_users  literacy_rate  \
# 3    Japan  1206263687  12473835857216      1112451555           97.5
# 13   Spain   898664919  15275513099842       794943861           60.6
# 1    China   792846414   5086547998939       685275917           82.2
#
#     internet_penetration_rate
# 3                   92.222917
# 13                  88.458317
# 1                   86.432366

# %%
# Calculate average literacy rate across countries
merged_df['literacy_rate'].mean()
# Out:
# np.float64(78.43)

# %%
merged_df[['population', 'GDP', 'internet_users', 'literacy_rate']].corr()
# Out:
#                 population       GDP  internet_users  literacy_rate
# population        1.000000  0.183118        0.749573      -0.229585
# GDP               0.183118  1.000000        0.212559      -0.081700
# internet_users    0.749573  0.212559        1.000000       0.074808
# literacy_rate    -0.229585 -0.081700        0.074808       1.000000

# %%
# Load into SQLite:
# # Create an SQLite database
import sqlite3
conn = sqlite3.connect('country_data.db')

# Load the final merged dataset into a database table
merged_df.to_sql('country_data', conn, index=False, if_exists='replace')
# Out:
# 20

# %%
pd.read_sql_query('select * from country_data', conn)
# Out:
#            country  population             GDP  internet_users  literacy_rate  \
# 0    United States  1278642419  10450436373455       745595490           72.7
# 1            China   792846414   5086547998939       685275917           82.2
# 2            India  1001406378  14540718118693       606850704           80.3
# 3            Japan  1206263687  12473835857216      1112451555           97.5
# 4          Germany   428734972   2038442396490       246827121           92.9
# 5           Russia   420968276  10987125474745       162156967           89.1
# 6           Brazil   675094950   8793052816619        24027075           81.0
# 7   United Kingdom   674991378  11799848684255       266047041           82.9
# 8           France   434389014   7758669752269       216417853           97.6
# 9            Italy   254467210  12907234326850        87191493           83.7
# 10          Canada  1438267572   8158351525190       894102645           70.8
# ...

# %%
#  Write and execute SQL queries to extract insights
# a. Countries with highest internet penetration
pd.read_sql_query('select * from country_data order by internet_penetration_rate desc limit 3', conn)
# Out:
#   country  population             GDP  internet_users  literacy_rate  \
# 0   Japan  1206263687  12473835857216      1112451555           97.5
# 1   Spain   898664919  15275513099842       794943861           60.6
# 2   China   792846414   5086547998939       685275917           82.2
#
#    internet_penetration_rate
# 0                  92.222917
# 1                  88.458317
# 2                  86.432366

# %%
# b. Average literacy rate
pd.read_sql_query('select avg(literacy_rate) from country_data', conn)
# Out:
#    avg(literacy_rate)
# 0               78.43

# %%
# c. Correlation between literacy rate and internet penetration
merged_df['literacy_rate'].corr(merged_df['internet_penetration_rate'])
# Out:
# np.float64(0.23533009202707547)

# %%
# d. GDP per capita analysis
pd.read_sql_query('select country, GDP/population as GDP_per_capita from country_data order by GDP_per_capita desc', conn)
# Out:
#            country  GDP_per_capita
# 0        Indonesia          132792
# 1            Italy           50722
# 2           Russia           26099
# 3           France           17861
# 4   United Kingdom           17481
# 5            Spain           16998
# 6            India           14520
# 7           Brazil           13024
# 8        Australia           12393
# 9      South Korea           10609
# 10          Turkey           10437
# 11           Japan           10340
# 12    Saudi Arabia            9239
# 13   United States            8173
# 14           China            6415
# 15       Argentina            6118
# 16          Canada            5672
# 17         Germany            4754
# 18          Mexico            4249
# 19    South Africa            3630

# %%
# e. Which countries have a GDP per capita above $10,000?
pd.read_sql_query('select country, GDP/population as GDP_per_capita from country_data where GDP_per_capita > 10000', conn)
# Out:
#            country  GDP_per_capita
# 0            India           14520
# 1            Japan           10340
# 2           Russia           26099
# 3           Brazil           13024
# 4   United Kingdom           17481
# 5           France           17861
# 6            Italy           50722
# 7        Australia           12393
# 8      South Korea           10609
# 9            Spain           16998
# 10       Indonesia          132792
# 11          Turkey           10437

# %%
# f. What is the total population covered in the dataset?
pd.read_sql_query('select sum(population) as total_population from country_data', conn)
# Out:
#    total_population
# 0       14864685089

# %%
# g. Which countries have the lowest literacy rates, and how does that impact internet access?

pd.read_sql_query('select country, literacy_rate, internet_penetration_rate from country_data order by literacy_rate limit 5', conn)
# Out:
#         country  literacy_rate  internet_penetration_rate
# 0  Saudi Arabia           60.5                  11.366429
# 1         Spain           60.6                  88.458317
# 2   South Korea           66.4                  47.165661
# 3     Argentina           67.8                  29.415710
# 4        Canada           70.8                  62.165251

# %%
merged_df['literacy_rate'].corr(merged_df['internet_penetration_rate'])
# Out:
# np.float64(0.23533009202707547)

# %%
#h. What are the top 5 wealthiest countries by total GDP, and how does that compare
# with population size?

pd.read_sql_query('select country, GDP from country_data order by GDP desc limit 5', conn)
# Out:
#      country             GDP
# 0      Spain  15275513099842
# 1      India  14540718118693
# 2      Italy  12907234326850
# 3      Japan  12473835857216
# 4  Indonesia  12404144955318

# %%
merged_df['population'].corr(merged_df['GDP'])
# Out:
# np.float64(0.18311848384796608)

# %%
#i.  Find countries where internet users exceed 70% of the population
pd.read_sql_query('select country from country_data where internet_users > 0.7 * population', conn)
# Out:
#         country
# 0         China
# 1         Japan
# 2         Spain
# 3  South Africa

# %%
# j. What is the average GDP per capita for countries with internet penetration above 50%?

pd.read_sql_query('''select avg(gdp_per_capita)
                     from (select gdp/population as gdp_per_capita
                           from country_data where internet_penetration_rate > 50)''', conn)
# Out:
#    avg(gdp_per_capita)
# 0          8993.222222

# %%
# k. How many countries have a literacy rate above 90%, and what is their average internet penetration?

pd.read_sql_query('select country from country_data where literacy_rate > 90', conn)
# Out:
#    country
# 0    Japan
# 1  Germany
# 2   France

# %%
pd.read_sql_query('select avg(internet_penetration_rate) from country_data where literacy_rate > 90', conn)
# Out:
#    avg(internet_penetration_rate)
# 0                       66.538383
